# %% [markdown]
# # Deliverable 1: Retrieve Weather Data
#
# 3. Create a new set of 2,000 random latitudes and longitudes.

# %%
# Import the dependencies.
import pandas as pd
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %% [markdown]
# # Deliverable 1: Retrieve Weather Data
#
# 4. Get the nearest city using the citipy module.

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %% [markdown]
# # Deliverable 1: Retrieve Weather Data
#
# 5. Perform an API call with the OpenWeatherMap.

# %%
# Import the requests library.
import requests

# Import the API key.
from config2 import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %% [markdown]
# # Deliverable 1: Retrieve Weather Data
#
# 6. Retrieve the following information from the API call:
#
# - Latitude and longitude
# - Maximum temperature
# - Percent humidity
# - Percent cloudiness
# - Wind speed
# - Weather description (for example, clouds, fog, light rain, clear sky)

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_conditions = city_weather["weather"][0]["main"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_conditions,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | jamestown
# Processing Record 2 of Set 1 | baykit
# Processing Record 3 of Set 1 | arraial do cabo
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | bethel
# Processing Record 6 of Set 1 | nanortalik
# Processing Record 7 of Set 1 | adrar
# Processing Record 8 of Set 1 | sao filipe
# Processing Record 9 of Set 1 | hamilton
# Processing Record 10 of Set 1 | utiroa
# City not found. Skipping...
# Processing Record 11 of Set 1 | abu kamal
# Processing Record 12 of Set 1 | susangerd
# Processing Record 13 of Set 1 | cape town
# Processing Record 14 of Set 1 | nikolskoye
# Processing Record 15 of Set 1 | veraval
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | aklavik
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | kyle of lochalsh
# City not found. Skipping...
# Processing Record 20 of Set 1 | we
# City not found. Skipping...
# Processing Record 21 of Set 1 | severo-kurilsk
# Processing Record 22 of Set 1 | bluff
# Processing Record 23 of Set 1 | camacupa
# Processing Record 24 of Set 1 | leshukonskoye
# Processing Record 25 of Set 1 | hobart
# Processing Record 26 of Set 1 | yellowknife
# Processing Record 27 of Set 1 | chuy
# Processing Record 28 of Set 1 | tuktoyaktuk
# Processing Record 29 of Set 1 | avarua
# Processing Record 30 of Set 1 | codrington
# Processing Record 31 of Set 1 | namatanai
# Processing Record 32 of Set 1 | albany
# Processing Record 33 of Set 1 | benghazi
# Processing Record 34 of Set 1 | chapais
# Processing Record 35 of Set 1 | kapaa
# Processing Record 36 of Set 1 | butaritari
# Processing Record 37 of Set 1 | dikson
# Processing Record 38 of Set 1 | klaksvik
# Processing Record 39 of Set 1 | qaanaaq
# Processing Record 40 of Set 1 | broome
# Processing Record 41 of Set 1 | port elizabeth
# Processing Record 42 of Set 1 | leh
# Processing Record 43 of Set 1 | mason city
# Processing Record 44 of Set 1 | mar del plata
# Processing Record 45 of Set 1 | atuona
# Processing Record 46 of Set 1 | east london
# Processing Record 47 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 1 | tecolutla
# Processing Record 49 of Set 1 | ijaki
# City not found. Skipping...
# Processing Record 50 of Set 1 | clarence town
# Processing Record 1 of Set 2 | vaitape
# Processing Record 2 of Set 2 | saskylakh
# Processing Record 3 of Set 2 | isangel
# Processing Record 4 of Set 2 | puerto ayora
# Processing Record 5 of Set 2 | acarau
# Processing Record 6 of Set 2 | punta arenas
# Processing Record 7 of Set 2 | kaura namoda
# Processing Record 8 of Set 2 | iqaluit
# Processing Record 9 of Set 2 | mandalgovi
# Processing Record 10 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 2 | felanitx
# Processing Record 12 of Set 2 | hithadhoo
# Processing Record 13 of Set 2 | orange
# Processing Record 14 of Set 2 | kirkwall
# Processing Record 15 of Set 2 | katsuura
# Processing Record 16 of Set 2 | cabo san lucas
# Processing Record 17 of Set 2 | lavrentiya
# Processing Record 18 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 2 | clyde river
# Processing Record 20 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 2 | te anau
# Processing Record 23 of Set 2 | upernavik
# Processing Record 24 of Set 2 | teya
# Processing Record 25 of Set 2 | khatanga
# Processing Record 26 of Set 2 | tulum
# Processing Record 27 of Set 2 | goderich
# Processing Record 28 of Set 2 | bredy
# Processing Record 29 of Set 2 | beringovskiy
# Processing Record 30 of Set 2 | ahipara
# Processing Record 31 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 2 | rikitea
# Processing Record 33 of Set 2 | inhambane
# Processing Record 34 of Set 2 | port alfred
# Processing Record 35 of Set 2 | ulaangom
# Processing Record 36 of Set 2 | hilo
# Processing Record 37 of Set 2 | slidell
# Processing Record 38 of Set 2 | neya
# Processing Record 39 of Set 2 | quatre cocos
# Processing Record 40 of Set 2 | ilulissat
# Processing Record 41 of Set 2 | pevek
# Processing Record 42 of Set 2 | groningen
# Processing Record 43 of Set 2 | valga
# Processing Record 44 of Set 2 | aksarka
# Processing Record 45 of Set 2 | aksu
# Processing Record 46 of Set 2 | eisenhuttenstadt
# City not found. Skipping...
# Processing Record 47 of Set 2 | vaini
# Processing Record 48 of Set 2 | pochutla
# Processing Record 49 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 1 of Set 3 | ponta do sol
# Processing Record 2 of Set 3 | tokur
# Processing Record 3 of Set 3 | norman wells
# Processing Record 4 of Set 3 | souillac
# Processing Record 5 of Set 3 | faya
# Processing Record 6 of Set 3 | georgetown
# Processing Record 7 of Set 3 | morondava
# Processing Record 8 of Set 3 | north bend
# Processing Record 9 of Set 3 | bredasdorp
# Processing Record 10 of Set 3 | kvareli
# Processing Record 11 of Set 3 | cuamba
# Processing Record 12 of Set 3 | saint-philippe
# Processing Record 13 of Set 3 | castro
# Processing Record 14 of Set 3 | inirida
# Processing Record 15 of Set 3 | coihaique
# Processing Record 16 of Set 3 | karasjok
# Processing Record 17 of Set 3 | puerto escondido
# Processing Record 18 of Set 3 | xinan
# Processing Record 19 of Set 3 | edd
# Processing Record 20 of Set 3 | barra do garcas
# Processing Record 21 of Set 3 | northam
# Processing Record 22 of Set 3 | great yarmouth
# Processing Record 23 of Set 3 | yumen
# Processing Record 24 of Set 3 | nanpiao
# Processing Record 25 of Set 3 | darnah
# Processing Record 26 of Set 3 | setermoen
# Processing Record 27 of Set 3 | mount isa
# Processing Record 28 of Set 3 | lorengau
# Processing Record 29 of Set 3 | lebu
# Processing Record 30 of Set 3 | saint george
# Processing Record 31 of Set 3 | kumo
# Processing Record 32 of Set 3 | kaitangata
# Processing Record 33 of Set 3 | ossora
# Processing Record 34 of Set 3 | coahuayana
# Processing Record 35 of Set 3 | taltal
# Processing Record 36 of Set 3 | puerto del rosario
# Processing Record 37 of Set 3 | sabya
# Processing Record 38 of Set 3 | airai
# Processing Record 39 of Set 3 | atbasar
# Processing Record 40 of Set 3 | carnarvon
# Processing Record 41 of Set 3 | puerto lleras
# Processing Record 42 of Set 3 | nautla
# Processing Record 43 of Set 3 | vardo
# Processing Record 44 of Set 3 | dharchula
# Processing Record 45 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 46 of Set 3 | lianzhou
# Processing Record 47 of Set 3 | mongu
# Processing Record 48 of Set 3 | takoradi
# Processing Record 49 of Set 3 | sur
# Processing Record 50 of Set 3 | new norfolk
# Processing Record 1 of Set 4 | padang
# Processing Record 2 of Set 4 | kavaratti
# Processing Record 3 of Set 4 | bethausen
# Processing Record 4 of Set 4 | lovrenc na pohorju
# Processing Record 5 of Set 4 | lompoc
# Processing Record 6 of Set 4 | booue
# Processing Record 7 of Set 4 | mitsamiouli
# Processing Record 8 of Set 4 | yabrud
# Processing Record 9 of Set 4 | dombarovskiy
# Processing Record 10 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 4 | beira
# Processing Record 12 of Set 4 | tiksi
# Processing Record 13 of Set 4 | hermanus
# Processing Record 14 of Set 4 | namibe
# Processing Record 15 of Set 4 | ngunguru
# Processing Record 16 of Set 4 | leningradskiy
# Processing Record 17 of Set 4 | pimenteiras
# Processing Record 18 of Set 4 | kalachinsk
# Processing Record 19 of Set 4 | barrow
# Processing Record 20 of Set 4 | sadat
# Processing Record 21 of Set 4 | batagay-alyta
# Processing Record 22 of Set 4 | sindor
# Processing Record 23 of Set 4 | kirya
# Processing Record 24 of Set 4 | bandarbeyla
# Processing Record 25 of Set 4 | dargaville
# Processing Record 26 of Set 4 | vila velha
# Processing Record 27 of Set 4 | mahebourg
# Processing Record 28 of Set 4 | ribeira grande
# Processing Record 29 of Set 4 | skjervoy
# Processing Record 30 of Set 4 | tabialan
# City not found. Skipping...
# Processing Record 31 of Set 4 | bath
# Processing Record 32 of Set 4 | santa lucia
# Processing Record 33 of Set 4 | koutiala
# Processing Record 34 of Set 4 | mandera
# Processing Record 35 of Set 4 | fort frances
# Processing Record 36 of Set 4 | sorland
# Processing Record 37 of Set 4 | planeta rica
# Processing Record 38 of Set 4 | martapura
# Processing Record 39 of Set 4 | hami
# Processing Record 40 of Set 4 | champua
# Processing Record 41 of Set 4 | general roca
# Processing Record 42 of Set 4 | labuhan
# Processing Record 43 of Set 4 | kruisfontein
# Processing Record 44 of Set 4 | longyearbyen
# Processing Record 45 of Set 4 | hofn
# Processing Record 46 of Set 4 | kiama
# Processing Record 47 of Set 4 | plettenberg bay
# Processing Record 48 of Set 4 | kayerkan
# Processing Record 49 of Set 4 | hastings
# Processing Record 50 of Set 4 | marsh harbour
# Processing Record 1 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 2 of Set 5 | havelock
# Processing Record 3 of Set 5 | cockburn harbour
# City not found. Skipping...
# Processing Record 4 of Set 5 | hede
# Processing Record 5 of Set 5 | ilam
# Processing Record 6 of Set 5 | praia da vitoria
# Processing Record 7 of Set 5 | partizanskoye
# Processing Record 8 of Set 5 | olafsvik
# Processing Record 9 of Set 5 | provideniya
# Processing Record 10 of Set 5 | basay
# Processing Record 11 of Set 5 | camacha
# Processing Record 12 of Set 5 | alanya
# Processing Record 13 of Set 5 | grindavik
# Processing Record 14 of Set 5 | saint-francois
# Processing Record 15 of Set 5 | gazojak
# Processing Record 16 of Set 5 | sooke
# Processing Record 17 of Set 5 | taoudenni
# Processing Record 18 of Set 5 | kavieng
# Processing Record 19 of Set 5 | tromso
# Processing Record 20 of Set 5 | hobyo
# Processing Record 21 of Set 5 | macheng
# Processing Record 22 of Set 5 | laguna
# Processing Record 23 of Set 5 | simao
# Processing Record 24 of Set 5 | traralgon
# Processing Record 25 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 5 | kaeo
# Processing Record 27 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 28 of Set 5 | tolaga bay
# Processing Record 29 of Set 5 | tiarei
# Processing Record 30 of Set 5 | seinajoki
# Processing Record 31 of Set 5 | turukhansk
# Processing Record 32 of Set 5 | kot isa khan
# Processing Record 33 of Set 5 | bozoum
# Processing Record 34 of Set 5 | janakpur
# Processing Record 35 of Set 5 | almeirim
# Processing Record 36 of Set 5 | saint anthony
# Processing Record 37 of Set 5 | paoua
# Processing Record 38 of Set 5 | san blas
# Processing Record 39 of Set 5 | saint paul
# Processing Record 40 of Set 5 | vostok
# Processing Record 41 of Set 5 | luderitz
# Processing Record 42 of Set 5 | tomatlan
# Processing Record 43 of Set 5 | muli
# Processing Record 44 of Set 5 | kodiak
# Processing Record 45 of Set 5 | sidhi
# Processing Record 46 of Set 5 | yeppoon
# Processing Record 47 of Set 5 | puteyets
# Processing Record 48 of Set 5 | berezovyy
# Processing Record 49 of Set 5 | nouadhibou
# Processing Record 50 of Set 5 | suzhou
# Processing Record 1 of Set 6 | karratha
# Processing Record 2 of Set 6 | manching
# Processing Record 3 of Set 6 | bandrele
# Processing Record 4 of Set 6 | hanna
# Processing Record 5 of Set 6 | sao joao da barra
# Processing Record 6 of Set 6 | hurghada
# Processing Record 7 of Set 6 | mareeba
# Processing Record 8 of Set 6 | baruun-urt
# Processing Record 9 of Set 6 | cap malheureux
# Processing Record 10 of Set 6 | sola
# Processing Record 11 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 6 | dalby
# Processing Record 13 of Set 6 | narsaq
# Processing Record 14 of Set 6 | chase
# Processing Record 15 of Set 6 | ararat
# Processing Record 16 of Set 6 | coquimbo
# Processing Record 17 of Set 6 | ulladulla
# Processing Record 18 of Set 6 | caravelas
# Processing Record 19 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 6 | walvis bay
# Processing Record 21 of Set 6 | sumbawa
# City not found. Skipping...
# Processing Record 22 of Set 6 | rach gia
# Processing Record 23 of Set 6 | los llanos de aridane
# Processing Record 24 of Set 6 | breytovo
# Processing Record 25 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 26 of Set 6 | tasiilaq
# Processing Record 27 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 28 of Set 6 | sorrento
# Processing Record 29 of Set 6 | falealupo
# City not found. Skipping...
# Processing Record 30 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 6 | fengcheng
# Processing Record 32 of Set 6 | pangai
# Processing Record 33 of Set 6 | at-bashi
# Processing Record 34 of Set 6 | maneadero
# Processing Record 35 of Set 6 | lucapa
# Processing Record 36 of Set 6 | smithers
# Processing Record 37 of Set 6 | atherton
# Processing Record 38 of Set 6 | talawdi
# City not found. Skipping...
# Processing Record 39 of Set 6 | harrison
# Processing Record 40 of Set 6 | tura
# Processing Record 41 of Set 6 | bengkulu
# Processing Record 42 of Set 6 | erzin
# Processing Record 43 of Set 6 | dingle
# Processing Record 44 of Set 6 | yar-sale
# Processing Record 45 of Set 6 | dunedin
# Processing Record 46 of Set 6 | viedma
# Processing Record 47 of Set 6 | mogadishu
# Processing Record 48 of Set 6 | gerash
# Processing Record 49 of Set 6 | egvekinot
# Processing Record 50 of Set 6 | huilong
# Processing Record 1 of Set 7 | sinnamary
# Processing Record 2 of Set 7 | avera
# Processing Record 3 of Set 7 | acapulco
# Processing Record 4 of Set 7 | auki
# Processing Record 5 of Set 7 | acajutla
# Processing Record 6 of Set 7 | kearney
# Processing Record 7 of Set 7 | thyboron
# Processing Record 8 of Set 7 | dubbo
# Processing Record 9 of Set 7 | lata
# Processing Record 10 of Set 7 | tananger
# Processing Record 11 of Set 7 | pisco
# Processing Record 12 of Set 7 | bentiu
# Processing Record 13 of Set 7 | orbetello
# Processing Record 14 of Set 7 | jumla
# Processing Record 15 of Set 7 | klaebu
# Processing Record 16 of Set 7 | maumere
# Processing Record 17 of Set 7 | matara
# Processing Record 18 of Set 7 | santa
# Processing Record 19 of Set 7 | talnakh
# Processing Record 20 of Set 7 | khandagayty
# Processing Record 21 of Set 7 | strezhevoy
# Processing Record 22 of Set 7 | dhidhdhoo
# Processing Record 23 of Set 7 | platteville
# Processing Record 24 of Set 7 | kimbe
# Processing Record 25 of Set 7 | bambous virieux
# Processing Record 26 of Set 7 | kununurra
# Processing Record 27 of Set 7 | comodoro rivadavia
# Processing Record 28 of Set 7 | la ronge
# Processing Record 29 of Set 7 | faanui
# Processing Record 30 of Set 7 | bumba
# Processing Record 31 of Set 7 | ostrovnoy
# Processing Record 32 of Set 7 | busayra
# Processing Record 33 of Set 7 | otjiwarongo
# Processing Record 34 of Set 7 | badou
# Processing Record 35 of Set 7 | husavik
# Processing Record 36 of Set 7 | portland
# Processing Record 37 of Set 7 | port blair
# Processing Record 38 of Set 7 | najran
# Processing Record 39 of Set 7 | torbay
# Processing Record 40 of Set 7 | constitucion
# Processing Record 41 of Set 7 | krasnyy yar
# Processing Record 42 of Set 7 | teshie
# Processing Record 43 of Set 7 | karatau
# Processing Record 44 of Set 7 | lasa
# Processing Record 45 of Set 7 | cabedelo
# Processing Record 46 of Set 7 | thompson
# Processing Record 47 of Set 7 | san quintin
# Processing Record 48 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 49 of Set 7 | yatou
# Processing Record 50 of Set 7 | mayo
# Processing Record 1 of Set 8 | beauly
# Processing Record 2 of Set 8 | juifang
# City not found. Skipping...
# Processing Record 3 of Set 8 | itoman
# Processing Record 4 of Set 8 | bay roberts
# Processing Record 5 of Set 8 | ancud
# Processing Record 6 of Set 8 | awbari
# Processing Record 7 of Set 8 | aksha
# Processing Record 8 of Set 8 | king city
# Processing Record 9 of Set 8 | machico
# Processing Record 10 of Set 8 | wahiawa
# Processing Record 11 of Set 8 | sabang
# Processing Record 12 of Set 8 | piacabucu
# Processing Record 13 of Set 8 | ciudad valles
# Processing Record 14 of Set 8 | kampot
# Processing Record 15 of Set 8 | moose factory
# Processing Record 16 of Set 8 | makasar
# Processing Record 17 of Set 8 | yining
# Processing Record 18 of Set 8 | eyl
# Processing Record 19 of Set 8 | itarema
# Processing Record 20 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 21 of Set 8 | rundu
# Processing Record 22 of Set 8 | mecca
# Processing Record 23 of Set 8 | akyab
# Processing Record 24 of Set 8 | san borja
# Processing Record 25 of Set 8 | cruz
# Processing Record 26 of Set 8 | semey
# Processing Record 27 of Set 8 | oistins
# Processing Record 28 of Set 8 | am timan
# Processing Record 29 of Set 8 | geraldton
# Processing Record 30 of Set 8 | lagoa
# Processing Record 31 of Set 8 | fortuna
# Processing Record 32 of Set 8 | maceio
# Processing Record 33 of Set 8 | flin flon
# Processing Record 34 of Set 8 | kobryn
# Processing Record 35 of Set 8 | puerto colombia
# Processing Record 36 of Set 8 | portobelo
# Processing Record 37 of Set 8 | tijara
# Processing Record 38 of Set 8 | yoichi
# Processing Record 39 of Set 8 | benicarlo
# Processing Record 40 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 41 of Set 8 | umm lajj
# Processing Record 42 of Set 8 | boa vista
# Processing Record 43 of Set 8 | jingdezhen
# Processing Record 44 of Set 8 | coronado
# Processing Record 45 of Set 8 | bereda
# Processing Record 46 of Set 8 | zambezi
# Processing Record 47 of Set 8 | kalangala
# Processing Record 48 of Set 8 | minas
# Processing Record 49 of Set 8 | richards bay
# Processing Record 50 of Set 8 | zelenogorskiy
# Processing Record 1 of Set 9 | charters towers
# Processing Record 2 of Set 9 | juneau
# Processing Record 3 of Set 9 | murakami
# Processing Record 4 of Set 9 | tecpan
# Processing Record 5 of Set 9 | caconde
# Processing Record 6 of Set 9 | charlottetown
# Processing Record 7 of Set 9 | cockburn town
# Processing Record 8 of Set 9 | port hardy
# Processing Record 9 of Set 9 | ghanzi
# Processing Record 10 of Set 9 | aysha
# Processing Record 11 of Set 9 | salinas
# Processing Record 12 of Set 9 | wamba
# Processing Record 13 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 9 | bossembele
# City not found. Skipping...
# Processing Record 15 of Set 9 | poum
# Processing Record 16 of Set 9 | guerrero negro
# Processing Record 17 of Set 9 | nkhotakota
# Processing Record 18 of Set 9 | bandundu
# Processing Record 19 of Set 9 | hukuntsi
# Processing Record 20 of Set 9 | salalah
# Processing Record 21 of Set 9 | paamiut
# Processing Record 22 of Set 9 | okhotsk
# Processing Record 23 of Set 9 | saint-louis
# Processing Record 24 of Set 9 | lazaro cardenas
# Processing Record 25 of Set 9 | kempele
# Processing Record 26 of Set 9 | morehead
# Processing Record 27 of Set 9 | orlik
# Processing Record 28 of Set 9 | bathsheba
# Processing Record 29 of Set 9 | naryan-mar
# Processing Record 30 of Set 9 | seymchan
# Processing Record 31 of Set 9 | suntar
# Processing Record 32 of Set 9 | chifeng
# Processing Record 33 of Set 9 | yeehaw junction
# City not found. Skipping...
# Processing Record 34 of Set 9 | bealanana
# Processing Record 35 of Set 9 | isla vista
# Processing Record 36 of Set 9 | fereydun kenar
# Processing Record 37 of Set 9 | la asuncion
# Processing Record 38 of Set 9 | belyy yar
# Processing Record 39 of Set 9 | deputatskiy
# Processing Record 40 of Set 9 | udachnyy
# Processing Record 41 of Set 9 | san patricio
# Processing Record 42 of Set 9 | thunder bay
# Processing Record 43 of Set 9 | yenagoa
# Processing Record 44 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 45 of Set 9 | zyrardow
# Processing Record 46 of Set 9 | susanville
# Processing Record 47 of Set 9 | margate
# Processing Record 48 of Set 9 | izumo
# Processing Record 49 of Set 9 | elko
# Processing Record 50 of Set 9 | sanandaj
# Processing Record 1 of Set 10 | berlevag
# Processing Record 2 of Set 10 | wangqing
# Processing Record 3 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 10 | sao jose da coroa grande
# Processing Record 5 of Set 10 | chokurdakh
# Processing Record 6 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 10 | valence
# Processing Record 8 of Set 10 | esperance
# Processing Record 9 of Set 10 | kutum
# Processing Record 10 of Set 10 | tadine
# Processing Record 11 of Set 10 | millau
# Processing Record 12 of Set 10 | queenstown
# Processing Record 13 of Set 10 | krasnogorsk
# Processing Record 14 of Set 10 | waingapu
# Processing Record 15 of Set 10 | manggar
# Processing Record 16 of Set 10 | bonnyville
# Processing Record 17 of Set 10 | lethem
# Processing Record 18 of Set 10 | tsumeb
# Processing Record 19 of Set 10 | port augusta
# Processing Record 20 of Set 10 | zunyi
# Processing Record 21 of Set 10 | muyezerskiy
# Processing Record 22 of Set 10 | tateyama
# Processing Record 23 of Set 10 | cherskiy
# Processing Record 24 of Set 10 | bac lieu
# Processing Record 25 of Set 10 | taywarah
# Processing Record 26 of Set 10 | caldas novas
# Processing Record 27 of Set 10 | preobrazheniye
# Processing Record 28 of Set 10 | djambala
# Processing Record 29 of Set 10 | svetlaya
# Processing Record 30 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 31 of Set 10 | zyryanka
# Processing Record 32 of Set 10 | jasper
# Processing Record 33 of Set 10 | deqing
# Processing Record 34 of Set 10 | fort nelson
# Processing Record 35 of Set 10 | shache
# Processing Record 36 of Set 10 | ishigaki
# Processing Record 37 of Set 10 | hasaki
# Processing Record 38 of Set 10 | praia
# Processing Record 39 of Set 10 | zapresic
# Processing Record 40 of Set 10 | verkhoyansk
# Processing Record 41 of Set 10 | gorontalo
# Processing Record 42 of Set 10 | angoche
# Processing Record 43 of Set 10 | cidreira
# Processing Record 44 of Set 10 | matamoros
# Processing Record 45 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 46 of Set 10 | san policarpo
# Processing Record 47 of Set 10 | kerema
# Processing Record 48 of Set 10 | riohacha
# Processing Record 49 of Set 10 | lillooet
# Processing Record 50 of Set 10 | kvarkeno
# Processing Record 1 of Set 11 | soyo
# Processing Record 2 of Set 11 | college
# Processing Record 3 of Set 11 | puerto suarez
# Processing Record 4 of Set 11 | camden
# Processing Record 5 of Set 11 | rondonopolis
# Processing Record 6 of Set 11 | onguday
# Processing Record 7 of Set 11 | port lincoln
# Processing Record 8 of Set 11 | port hawkesbury
# Processing Record 9 of Set 11 | sorong
# Processing Record 10 of Set 11 | dangara
# Processing Record 11 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 11 | kifri
# Processing Record 13 of Set 11 | santa marta
# Processing Record 14 of Set 11 | atambua
# Processing Record 15 of Set 11 | athabasca
# Processing Record 16 of Set 11 | sataua
# City not found. Skipping...
# Processing Record 17 of Set 11 | bayangol
# Processing Record 18 of Set 11 | makakilo city
# Processing Record 19 of Set 11 | wanaka
# Processing Record 20 of Set 11 | el alto
# Processing Record 21 of Set 11 | katghora
# Processing Record 22 of Set 11 | chumikan
# Processing Record 23 of Set 11 | aykhal
# Processing Record 24 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 11 | oneida
# Processing Record 26 of Set 11 | roma
# Processing Record 27 of Set 11 | lensk
# Processing Record 28 of Set 11 | thongwa
# Processing Record 29 of Set 11 | puerto madryn
# Processing Record 30 of Set 11 | corner brook
# Processing Record 31 of Set 11 | nyurba
# Processing Record 32 of Set 11 | angra
# City not found. Skipping...
# Processing Record 33 of Set 11 | eldoret
# Processing Record 34 of Set 11 | vanimo
# Processing Record 35 of Set 11 | kahului
# Processing Record 36 of Set 11 | monterey
# Processing Record 37 of Set 11 | rio gallegos
# Processing Record 38 of Set 11 | maracacume
# Processing Record 39 of Set 11 | port-gentil
# Processing Record 40 of Set 11 | aranos
# Processing Record 41 of Set 11 | bad freienwalde
# Processing Record 42 of Set 11 | thinadhoo
# Processing Record 43 of Set 11 | ballina
# Processing Record 44 of Set 11 | dalbandin
# Processing Record 45 of Set 11 | novi ligure
# Processing Record 46 of Set 11 | stykkisholmur
# Processing Record 47 of Set 11 | borogontsy
# Processing Record 48 of Set 11 | skagastrond
# City not found. Skipping...
# Processing Record 49 of Set 11 | sabha
# Processing Record 50 of Set 11 | keningau
# Processing Record 1 of Set 12 | viamao
# Processing Record 2 of Set 12 | trinidad
# Processing Record 3 of Set 12 | kundla
# Processing Record 4 of Set 12 | singapore
# Processing Record 5 of Set 12 | serafimovich
# Processing Record 6 of Set 12 | moron
# Processing Record 7 of Set 12 | mopti
# Processing Record 8 of Set 12 | manokwari
# Processing Record 9 of Set 12 | mbandaka
# Processing Record 10 of Set 12 | coolum beach
# Processing Record 11 of Set 12 | negombo
# Processing Record 12 of Set 12 | saldanha
# Processing Record 13 of Set 12 | nelson bay
# Processing Record 14 of Set 12 | buraydah
# Processing Record 15 of Set 12 | fare
# Processing Record 16 of Set 12 | lucea
# Processing Record 17 of Set 12 | hambantota
# Processing Record 18 of Set 12 | hervey bay
# Processing Record 19 of Set 12 | lanigan
# Processing Record 20 of Set 12 | malinovskiy
# Processing Record 21 of Set 12 | la tuque
# Processing Record 22 of Set 12 | ormara
# Processing Record 23 of Set 12 | belaya gora
# Processing Record 24 of Set 12 | slobodskoy
# Processing Record 25 of Set 12 | nkhata bay
# Processing Record 26 of Set 12 | sitka
# Processing Record 27 of Set 12 | qaqortoq
# Processing Record 28 of Set 12 | emmett
# Processing Record 29 of Set 12 | colan
# Processing Record 30 of Set 12 | colares
# Processing Record 31 of Set 12 | lodwar
# Processing Record 32 of Set 12 | ereymentau
# Processing Record 33 of Set 12 | otradnoye
# Processing Record 34 of Set 12 | natitingou
# Processing Record 35 of Set 12 | tubmanburg
# Processing Record 36 of Set 12 | tuatapere
# Processing Record 37 of Set 12 | ust-kulom
# Processing Record 38 of Set 12 | diego de almagro
# Processing Record 39 of Set 12 | kirakira
# Processing Record 40 of Set 12 | naze
# Processing Record 41 of Set 12 | shakawe
# Processing Record 42 of Set 12 | kalaikunda
# Processing Record 43 of Set 12 | qui nhon
# Processing Record 44 of Set 12 | cairns
# Processing Record 45 of Set 12 | mazagao
# Processing Record 46 of Set 12 | antofagasta
# Processing Record 47 of Set 12 | sohag
# Processing Record 48 of Set 12 | daru
# Processing Record 49 of Set 12 | tonantins
# Processing Record 50 of Set 12 | sisimiut
# Processing Record 1 of Set 13 | mehamn
# Processing Record 2 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 3 of Set 13 | wagar
# Processing Record 4 of Set 13 | umm bab
# Processing Record 5 of Set 13 | hangu
# Processing Record 6 of Set 13 | seoul
# Processing Record 7 of Set 13 | beyneu
# Processing Record 8 of Set 13 | san andres
# Processing Record 9 of Set 13 | rozivka
# Processing Record 10 of Set 13 | pacific grove
# Processing Record 11 of Set 13 | dniprorudne
# Processing Record 12 of Set 13 | alofi
# Processing Record 13 of Set 13 | bahia honda
# Processing Record 14 of Set 13 | tarrafal
# Processing Record 15 of Set 13 | zhezkazgan
# Processing Record 16 of Set 13 | gainesville
# Processing Record 17 of Set 13 | seia
# Processing Record 18 of Set 13 | clemson
# Processing Record 19 of Set 13 | maralal
# Processing Record 20 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 21 of Set 13 | rehoboth
# Processing Record 22 of Set 13 | xichang
# Processing Record 23 of Set 13 | santiago
# Processing Record 24 of Set 13 | korla
# Processing Record 25 of Set 13 | zarubino
# Processing Record 26 of Set 13 | ketchikan
# Processing Record 27 of Set 13 | cartagena
# Processing Record 28 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 13 | bodden town
# Processing Record 30 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 31 of Set 13 | quarai
# Processing Record 32 of Set 13 | aquiraz
# Processing Record 33 of Set 13 | sukkur
# Processing Record 34 of Set 13 | handwara
# City not found. Skipping...
# Processing Record 35 of Set 13 | batsfjord
# Processing Record 36 of Set 13 | batagay
# Processing Record 37 of Set 13 | koryazhma
# Processing Record 38 of Set 13 | moranbah
# Processing Record 39 of Set 13 | verkhnyaya maksakovka
# Processing Record 40 of Set 13 | hanzhong
# Processing Record 41 of Set 13 | khani
# Processing Record 42 of Set 13 | tommot
# Processing Record 43 of Set 13 | nara
# Processing Record 44 of Set 13 | ouricuri
# Processing Record 45 of Set 13 | ondorhaan
# City not found. Skipping...
# Processing Record 46 of Set 13 | dezhou
# Processing Record 47 of Set 13 | nanded
# City not found. Skipping...
# Processing Record 48 of Set 13 | amapa
# Processing Record 49 of Set 13 | odweyne
# Processing Record 50 of Set 13 | shingu
# Processing Record 1 of Set 14 | harper
# Processing Record 2 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 3 of Set 14 | goundam
# Processing Record 4 of Set 14 | sao felix do xingu
# Processing Record 5 of Set 14 | jinchang
# Processing Record 6 of Set 14 | bacuit
# City not found. Skipping...
# Processing Record 7 of Set 14 | katha
# City not found. Skipping...
# Processing Record 8 of Set 14 | wajima
# Processing Record 9 of Set 14 | rabo de peixe
# Processing Record 10 of Set 14 | umtata
# Processing Record 11 of Set 14 | kitami
# Processing Record 12 of Set 14 | druzhba
# Processing Record 13 of Set 14 | krasne
# Processing Record 14 of Set 14 | wattegama
# Processing Record 15 of Set 14 | nuevo progreso
# Processing Record 16 of Set 14 | shubarshi
# Processing Record 17 of Set 14 | otane
# Processing Record 18 of Set 14 | bulgan
# Processing Record 19 of Set 14 | indian head
# Processing Record 20 of Set 14 | oil city
# Processing Record 21 of Set 14 | muzquiz
# City not found. Skipping...
# Processing Record 22 of Set 14 | bachaquero
# Processing Record 23 of Set 14 | dublin
# Processing Record 24 of Set 14 | damghan
# Processing Record 25 of Set 14 | debre tabor
# Processing Record 26 of Set 14 | ipueiras
# Processing Record 27 of Set 14 | mount gambier
# Processing Record 28 of Set 14 | meulaboh
# Processing Record 29 of Set 14 | kranuan
# Processing Record 30 of Set 14 | ust-nera
# Processing Record 31 of Set 14 | sungaipenuh
# Processing Record 32 of Set 14 | langsa
# Processing Record 33 of Set 14 | dicabisagan
# Processing Record 34 of Set 14 | libenge
# Processing Record 35 of Set 14 | yulara
# Processing Record 36 of Set 14 | kamenka
# Processing Record 37 of Set 14 | bogorodskoye
# Processing Record 38 of Set 14 | touros
# Processing Record 39 of Set 14 | maragogi
# Processing Record 40 of Set 14 | bokajan
# Processing Record 41 of Set 14 | cubuk
# Processing Record 42 of Set 14 | bahia blanca
# Processing Record 43 of Set 14 | ende
# Processing Record 44 of Set 14 | porto belo
# Processing Record 45 of Set 14 | kjollefjord
# Processing Record 46 of Set 14 | bilibino
# Processing Record 47 of Set 14 | nidzica
# Processing Record 48 of Set 14 | kambove
# Processing Record 49 of Set 14 | dawson creek
# Processing Record 50 of Set 14 | jerome
# Processing Record 1 of Set 15 | atar
# Processing Record 2 of Set 15 | karlstad
# Processing Record 3 of Set 15 | nemuro
# Processing Record 4 of Set 15 | cansuje
# Processing Record 5 of Set 15 | nuevo laredo
# Processing Record 6 of Set 15 | kitui
# Processing Record 7 of Set 15 | navirai
# Processing Record 8 of Set 15 | ridgecrest
# Processing Record 9 of Set 15 | marathon
# Processing Record 10 of Set 15 | sungurlu
# Processing Record 11 of Set 15 | nizwa
# Processing Record 12 of Set 15 | thames
# Processing Record 13 of Set 15 | mutsamudu
# City not found. Skipping...
# Processing Record 14 of Set 15 | gigmoto
# Processing Record 15 of Set 15 | komsomolskiy
# Processing Record 16 of Set 15 | alice springs
# Processing Record 17 of Set 15 | phibun mangsahan
# Processing Record 18 of Set 15 | ratzeburg
# Processing Record 19 of Set 15 | ndiekro
# City not found. Skipping...
# Processing Record 20 of Set 15 | muros
# Processing Record 21 of Set 15 | shemonaikha
# Processing Record 22 of Set 15 | sal rei
# Processing Record 23 of Set 15 | rosarito
# Processing Record 24 of Set 15 | benguela
# Processing Record 25 of Set 15 | vuktyl
# Processing Record 26 of Set 15 | carutapera
# Processing Record 27 of Set 15 | la union
# Processing Record 28 of Set 15 | solnechnyy
# Processing Record 29 of Set 15 | greymouth
# Processing Record 30 of Set 15 | iroquois falls
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# # Deliverable 1: Retrieve Weather Data
#
# 7. Add the data to a new DataFrame.
# - Before exporting your new DataFrame as a CSV file

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Jamestown  42.0970  -79.2353     67.01        76          75
# 1             Baykit  61.6700   96.3700     46.71        61          99
# 2    Arraial Do Cabo -22.9661  -42.0278     75.16        78          75
# 3            Mataura -46.1927  168.8643     40.48        90         100
# 4             Bethel  41.3712  -73.4140     70.02        90          78
# ..               ...      ...       ...       ...       ...         ...
# 668       Carutapera  -1.1950  -46.0200     76.46        90          85
# 669         La Union  -5.4000  -80.7500     81.43        43          13
# 670       Solnechnyy  50.7214  136.6319     45.05        98         100
# 671        Greymouth -42.4667  171.2000     45.88        85          32
# 672   Iroquois Falls  48.7669  -80.6831     60.66        73         100
#
#      Wind Speed Country Current Description                 Date
# 0          5.75      US              Clouds  2022-05-28 20:54:59
# 1          3.24      RU              Clouds  2022-05-28 20:55:00
# 2          9.22      BR              Clouds  2022-05-28 20:55:00
# 3          2.91      NZ              Clouds  2022-05-28 20:55:00
# 4          4.92      US                Rain  2022-05-28 20:55:01
# ..          ...     ...                 ...                  ...
# 668        3.94      BR              Clouds  2022-05-28 21:13:14
# 669       14.92      PE              Clouds  2022-05-28 21:13:14
# 670        2.06      RU              Clouds  2022-05-28 21:13:15
# 671        7.94      NZ              Clouds  2022-05-28 21:13:15
# 672        4.25      CA              Clouds  2022-05-28 21:13:15
#
# [673 rows x 10 columns]

# %%
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                 City Country                 Date      Lat       Lng  \
# 0          Jamestown      US  2022-05-28 20:54:59  42.0970  -79.2353
# 1             Baykit      RU  2022-05-28 20:55:00  61.6700   96.3700
# 2    Arraial Do Cabo      BR  2022-05-28 20:55:00 -22.9661  -42.0278
# 3            Mataura      NZ  2022-05-28 20:55:00 -46.1927  168.8643
# 4             Bethel      US  2022-05-28 20:55:01  41.3712  -73.4140
# ..               ...     ...                  ...      ...       ...
# 668       Carutapera      BR  2022-05-28 21:13:14  -1.1950  -46.0200
# 669         La Union      PE  2022-05-28 21:13:14  -5.4000  -80.7500
# 670       Solnechnyy      RU  2022-05-28 21:13:15  50.7214  136.6319
# 671        Greymouth      NZ  2022-05-28 21:13:15 -42.4667  171.2000
# 672   Iroquois Falls      CA  2022-05-28 21:13:15  48.7669  -80.6831
#
#      Max Temp  Humidity  Cloudiness  Wind Speed Current Description
# 0       67.01        76          75        5.75              Clouds
# 1       46.71        61          99        3.24              Clouds
# 2       75.16        78          75        9.22              Clouds
# 3       40.48        90         100        2.91              Clouds
# 4       70.02        90          78        4.92                Rain
# ..        ...       ...         ...         ...                 ...
# 668     76.46        90          85        3.94              Clouds
# 669     81.43        43          13       14.92              Clouds
# 670     45.05        98         100        2.06              Clouds
# 671     45.88        85          32        7.94              Clouds
# 672     60.66        73         100        4.25              Clouds
#
# [673 rows x 10 columns]

# %% [markdown]
# # Deliverable 1: Retrieve Weather Data
#
# 8. Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
